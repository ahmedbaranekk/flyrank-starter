# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ahmedbaranekk/flyrank-starter/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
#
# **Answer:**
# My lane is a **Ranking** task. The primary objective is to order items (e.g., content, creators, or search results) so that the most relevant items appear at the top. While the model might output a continuous score under the hood, the business action is strictly about the relative ordering presented to the end user.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
#
# **Answer:**
# The target is **Engagement Rate** (clicks, saves, or watch time). Because true "relevance" or "quality" is an abstract concept that we cannot measure directly, engagement serves as our behavioral proxy. This label comes directly from historical, observed user outcomes logged in our analytics database.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
#
# **Answer:**
# The success metric is **NDCG@10** (Normalized Discounted Cumulative Gain). Since this is a ranking task, getting the top few results right is exponentially more important than correctly ordering items at the bottom of the page. A "good" result means outperforming our current heuristic baseline, targeting an NDCG@10 of > 0.82.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*
#
# **Answer:**
# The unit of analysis is a **single user-item interaction**. One row = one specific piece of content displayed to one specific user at a given timestamp.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
#
#
# **Answer:**
# A fixed rule (e.g., `ORDER BY date_published DESC, total_likes DESC`) fails because user preferences are multi-dimensional and non-linear. An older post by a niche creator might be highly relevant to User A but entirely irrelevant to User B. ML beats fixed heuristics here because it can weigh these complex interaction features (user history × item attributes × temporal decay) simultaneously at scale.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
